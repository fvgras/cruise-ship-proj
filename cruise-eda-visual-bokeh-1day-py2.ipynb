# %%
## this ipynb for EDA the Data ##
from __future__ import print_function
from __future__ import division
from __future__ import unicode_literals

# %%
import pandas as pd
import numpy as np
import bokeh          ## visualize tool for browsers
from matplotlib import pyplot as plt
import seaborn as sns ##
#import tqdm          ##
from sklearn.ensemble        import GradientBoostingRegressor
from sklearn.model_selection import cross_val_predict, cross_val_score, KFold, train_test_split

# %matplotlib inline

# %%
## three CSVs ## captured 7/20/2017
cities =   './brandon-telle-cruise-ship-locations/data/output_cities.csv'                        ## 55k
location = './brandon-telle-cruise-ship-locations/data/output_daily_ship_location.csv'           ## 72Meg
ships =    './brandon-telle-cruise-ship-locations/data/output_ships.csv' ## wikipedia references ## 51k
## represents data from 2003 to 1H2017
## see https://data.world/brandon-telle/cruise-ship-locations/

# %%
df_c = pd.read_csv(cities)
df_l = pd.read_csv(location)
df_s = pd.read_csv(ships)
# only 2 seconds to read the

# %%
df_c.head()   ## id is string
# Out:
#                             id                        city country  \
# 0                          NaN  Port Vendres (Carcassonne)     NaN
# 1                          NaN    Puerto Quetzal (Antigua)     NaN
# 2  ChIJDRIsQgFvDowRDoJZqcp_5D0                  St. Martin     NaN
# 3  ChIJSyCNfAfJlEARrofUZIqAX3w                       Yalta     NaN
# 4  ChIJ4QD2vUx3zYgRYA13Gn5NKU4                      Havana    Cuba
#
#   country_code        lat        lon                             location
# 0          NaN        NaN        NaN                                  NaN
# 1          NaN        NaN        NaN                                  NaN
# 2          NaN  18.070830 -63.050081        POINT(18.0708298 -63.0500809)
# 3          NaN  44.495205  34.166301  POINT(44.495205000000013 34.166301)
# 4           CU  23.113592 -82.366596        POINT(23.1135925 -82.3665956)

# %%
df_l.head()
# Out:
#            ship_name callsign     major_cruise_line        date  \
# 0  Carnival Splendor     3EUS  Carnival Cruise Line  2013-10-24
# 1  Carnival Splendor     3EUS  Carnival Cruise Line  2015-12-14
# 2  Carnival Splendor     3EUS  Carnival Cruise Line  2017-01-22
# 3  Carnival Splendor     3EUS  Carnival Cruise Line  2014-12-24
# 4  Carnival Splendor     3EUS  Carnival Cruise Line  2014-09-11
#
#    meters_traveled  lat_start  lon_start  lat_end  lon_end  in_port  \
# 0    147030.321045    39.1000   -73.8000  40.4207 -73.7793     True
# 1         0.000000    25.3662   -79.9476  25.3662 -79.9476    False
# 2    304820.653095    22.9000   -78.8000  25.4292 -79.9503     True
# 3     14634.546541    20.6046   -86.9222  20.4845 -86.9793     True
# 4    230024.991854    43.2000   -65.8000  44.3935 -63.4628     True
#
#    stopped_minutes  num_periods                 port_city_id port_city_name  \
# 0              597           16  ChIJrV5odTNjx4kR8GwA-0fk4qk          Dover
# 1                0            1  ChIJEcHIDqKw2YgRZU-t3XHylv8          Miami
# 2              770           29  ChIJyduBuZl8L4kR0lBeSNMB7yo         Nassau
# 3              536           11  ChIJJ5PRsO_4To8R_IsBXK68LjQ        Cozumel
# 4              536           14  ChIJxesm0LsTRUsRW2dKWg1nkM0        Halifax
#
#   port_city_country
# 0                US
# 1                US
# 2                BS
# 3                MX
# 4                CA

# %%
df_s.head()     ## ship.name is the index
# Out:
#                 name callsign  \
# 0          Wind Surf    C6IO6
# 1         Marco Polo    C6JZ7
# 2     Seabourn Quest    C6YZ5
# 3             Oriana    ZCDU9
# 4  European Causeway    C6RG7
#
#                                                 wiki        imo         mmsi  \
# 0     https://en.wikipedia.org/wiki/Wind_Surf_(ship)        NaN          NaN
# 1        https://en.wikipedia.org/wiki/MS_Marco_Polo  6417097.0  308693000.0
# 2    https://en.wikipedia.org/wiki/MV_Seabourn_Quest  9483126.0  311038900.0
# 3     https://en.wikipedia.org/wiki/MV_Oriana_(1995)  9050137.0  310529000.0
# 4  https://en.wikipedia.org/wiki/MV_European_Caus...  9208394.0  311027000.0
#
#                                          cruise_line major_cruise_line  \
# 0  1990–1998: Club Med1998 onwards: Windstar Cruises             Other
# 1  1965–1980?: Baltic Shipping Company[1]1979?–19...             Other
# 2                               Seabourn Cruise Line             Other
# 3                                        P&O Cruises             Other
# 4                                        P&O Ferries             Other
#
#    year_built                                           class  gross_tonnage  \
# 0      1990.0                                             NaN            NaN
# 1      1964.0  Ivan Franko-class passenger ship → Ocean liner        22080.0
# 2      2011.0                          Seabourn Odyssey class        32477.0
# 3      1995.0                                             NaN        69840.0
# 4      2000.0                                             NaN        20646.0
#
#    decks  capacity  length      vessel_type     flag home_port
# 0    8.0     386.0  187.00              NaN      NaN       NaN
# 1    NaN     820.0  176.28  passengers ship  BAHAMAS    nassau
# 2   11.0     450.0  198.15  passengers ship  BAHAMAS    nassau
# 3   10.0       NaN  260.00  passengers ship  BERMUDA  hamilton
# 4    NaN     410.0  156.20               ro  BAHAMAS    nassau

# %%
## it properly reads the ndash(utf) object ##

# %%
##df_s.isnull().sum()   ## ships
#name                   0  ## PK, FK
#callsign               0
#wiki                   9   URLS mainly
#imo                   46   instant message 
#mmsi                  49   maritime mobile service identities
#cruise_line           36
#major_cruise_line      0
#year_built            55
#class                127
#gross_tonnage         38
#decks                110
#capacity              66
#length                93
#vessel_type           46
#flag                  47
#home_port             85

# %%
##df_c.isnull().sum()  ## cities
#id              2  ## scrub top two  entries  PK,FK
#city            0
#country         4  ## scrub top four entries
#country_code    4  ## same
#lat             2  ## 2
#lon             2
#location        2

# %%
##df_l.isnull().sum()   ## locations
#ship_name            3130  ## PK,FK
#callsign                0
#major_cruise_line    3130
#date                    0     object  s/b datetime
#meters_traveled         0
#lat_start               0
#lon_start               0
#lat_end                 0
#lon_end                 0
#in_port                 0
#stopped_minutes         0   ## numeric   ( zero to ...)
#num_periods             0   ## categorical (never zero, 1 to 49)
#port_city_id         1228
#port_city_name       1228
#port_city_country    1823
#df_l.dtypes

# %%
df_c.shape          # 518, 7
# Out:
# (518, 7)

# %%
df_s.shape          # 276, 16
# Out:
# (276, 16)

# %%
print( df_l.shape)                      # 503207, 15
df_l.memory_usage(index=True).sum()   # 56.8MegBytes
# Out:
# (503207, 15)
# 56862471

# %%
## Questions/ Thoughts ??
## What about cost per trip    ## Can I get price from another source
## Ship's average performance  ## Is it highly utilized, or under utilized?
## Ship's lifespan             ## How long do they last, or how quickly they retire?
## Is Ship's performance linked to their stock quote? ## yahoo-finance to get that data?

# %%
## problems ##
# Tableau <!> Internal Error - An unexpected error occurred and the opperation could not be completed. [Show Details]
# Watson Analytics has 65 medium quality (rating)

# %%
# this URL for distance formulas:   http://www.movable-type.co.uk/scripts/latlong.html
# cool map and downloaded the code:  https://www.tytai.com/gmap/distance/

# %%
# his Blog
# 1) which cruise line running the most ships?   Royal_Carabbean=25 CCL=24 Norwegian=16
# 2) how many Day/Ship combinations are missing data ?  83K
# 3) Most popular Ports?   Ft. Laud=3705, Vancouver=3236, Cozumel=3074,  Galveston?  Houston?  New Orleans?

# %%
# merge ships and locations
#df_l = pd.merge(df_l,df_s, left_on='ship_name', right_on='name')
## end up with callsign_x/y   and major_cruise_line_x/y (MORE CLEANUP)
df_l = pd.merge(df_l,df_s.rename(columns={'callsign': 'callsign_id', 'major_cruise_line': 'major_cruise_line_id'}), left_on='ship_name', right_on='name')

# %%
df_l.drop('callsign_id',         axis=1, inplace=True)
df_l.drop('major_cruise_line_id',axis=1, inplace=True)
df_l.drop('home_port',           axis=1, inplace=True)   # too much NaN data

# %%
# merge cities  (no need)
#df_l = pd.merge(df_l,df_c.rename(columns={'port_city_id': 'id', 'id': 'city_id'}), on='city_id')
print( df_l.shape )        ## 506377, 28
df_l.head()
# Out:
# (506377, 28)
#            ship_name callsign     major_cruise_line        date  \
# 0  Carnival Splendor     3EUS  Carnival Cruise Line  2013-10-24
# 1  Carnival Splendor     3EUS  Carnival Cruise Line  2015-12-14
# 2  Carnival Splendor     3EUS  Carnival Cruise Line  2017-01-22
# 3  Carnival Splendor     3EUS  Carnival Cruise Line  2014-12-24
# 4  Carnival Splendor     3EUS  Carnival Cruise Line  2014-09-11
#
#    meters_traveled  lat_start  lon_start  lat_end  lon_end  in_port   ...    \
# 0    147030.321045    39.1000   -73.8000  40.4207 -73.7793     True   ...
# 1         0.000000    25.3662   -79.9476  25.3662 -79.9476    False   ...
# 2    304820.653095    22.9000   -78.8000  25.4292 -79.9503     True   ...
# 3     14634.546541    20.6046   -86.9222  20.4845 -86.9793     True   ...
# 4    230024.991854    43.2000   -65.8000  44.3935 -63.4628     True   ...
#
#           mmsi            cruise_line year_built                       class  \
# 0  372808000.0  Carnival Cruise Lines     2008.0  Splendor-class cruise ship
# 1  372808000.0  Carnival Cruise Lines     2008.0  Splendor-class cruise ship
# 2  372808000.0  Carnival Cruise Lines     2008.0  Splendor-class cruise ship
# 3  372808000.0  Carnival Cruise Lines     2008.0  Splendor-class cruise ship
# 4  372808000.0  Carnival Cruise Lines     2008.0  Splendor-class cruise ship
#
#   gross_tonnage decks capacity  length      vessel_type    flag
# 0      113562.0  13.0   3006.0   290.0  passengers ship  PANAMA
# 1      113562.0  13.0   3006.0   290.0  passengers ship  PANAMA
# 2      113562.0  13.0   3006.0   290.0  passengers ship  PANAMA
# 3      113562.0  13.0   3006.0   290.0  passengers ship  PANAMA
# 4      113562.0  13.0   3006.0   290.0  passengers ship  PANAMA
#
# [5 rows x 28 columns]

# %%
#df_l['ship_name'].groupby(df_l['major_cruise_line_x']).value_counts()    # not sorted
#df_l['ship_name'].groupby(df_l['major_cruise_line_x']).count()
#df_l.loc[:,['ship_name','major_cruise_line_x']].head()
#df_l.loc[:,['ship_name','major_cruise_line_x']].groupby('major_cruise_line_x').head()
#df_l.loc[:,['ship_name','major_cruise_line_x']].drop_duplicates('ship_name').groupby('major_cruise_line_x').head()
df_l.loc[:,['ship_name','major_cruise_line']].drop_duplicates('ship_name').groupby('major_cruise_line').count().sort_values('ship_name',ascending=False)       

# Other    ## 146  (huge) fix with cleanup
# Royal    ## 25
# CCL      ## 23
# Norwegian## 16
# Holland  ## 15
# Out:
#                                ship_name
# major_cruise_line
# Other                                146
# Royal Caribbean International         25
# Carnival Cruise Line                  23
# Norwegian Cruise Line                 16
# Holland America Line                  15
# Costa Crociere                        14
# Princess Cruises                      14
# Celebrity Cruises                     11
# Silversea Cruises                      4
# Disney Cruises                         3

# %%
df_l.loc[:,['ship_name','major_cruise_line']].drop_duplicates('ship_name').loc[df_l['major_cruise_line'] =='Royal Caribbean International'].sort_values('ship_name')   
## 25
# Out:
#                        ship_name              major_cruise_line
# 315409     Adventure of The Seas  Royal Caribbean International
# 373243        Allure of the Seas  Royal Caribbean International
# 228855        Anthem Of The Seas  Royal Caribbean International
# 328394    Brilliance Of The Seas  Royal Caribbean International
# 275394   Enchantment of the Seas  Royal Caribbean International
# 320460      Explorer Of The Seas  Royal Caribbean International
# 349195       Freedom of the Seas  Royal Caribbean International
# 317868      Grandeur Of The Seas  Royal Caribbean International
# 365174  Independence of the Seas  Royal Caribbean International
# 329968             Island Escape  Royal Caribbean International
# 273986         Jewel Of The Seas  Royal Caribbean International
# 331300        Legend Of The Seas  Royal Caribbean International
# 356756       Liberty of The Seas  Royal Caribbean International
# 277363       Majesty of the Seas  Royal Caribbean International
# 271468       Mariner Of The Seas  Royal Caribbean International
# 267021     Navigator Of The Seas  Royal Caribbean International
# 371754         Oasis of the Seas  Royal Caribbean International
# 228193       Quantum Of The Seas  Royal Caribbean International
# 324168      Radiance Of The Seas  Royal Caribbean International
# 347137      Rhapsody Of The Seas  Royal Caribbean International
# 269880      Serenade Of The Seas  Royal Caribbean International
# 223339                 Sovereign  Royal Caribbean International
# 344575     Splendour Of The Seas  Royal Caribbean International
# 326226        Vision of The Seas  Royal Caribbean International
# 322301       Voyager Of The Seas  Royal Caribbean International

# %%
df_l.loc[:,['ship_name','major_cruise_line']].drop_duplicates('ship_name').loc[df_l['major_cruise_line'] =='Carnival Cruise Line'].sort_values('ship_name')
## 23
# Out:
#                 ship_name     major_cruise_line
# 179805  Carnival Conquest  Carnival Cruise Line
# 248239   Carnival Destiny  Carnival Cruise Line
# 161693   Carnival Freedom  Carnival Cruise Line
# 186635     Carnival Glory  Carnival Cruise Line
# 47480     Carnival Legend  Carnival Cruise Line
# 54460    Carnival Liberty  Carnival Cruise Line
# 45189    Carnival Miracle  Carnival Cruise Line
# 49349      Carnival Pride  Carnival Cruise Line
# 182639    Carnival Spirit  Carnival Cruise Line
# 0       Carnival Splendor  Carnival Cruise Line
# 250852   Carnival Triumph  Carnival Cruise Line
# 42632      Carnival Valor  Carnival Cruise Line
# 166866   Carnival Victory  Carnival Cruise Line
# 164091     Carnival Vista  Carnival Cruise Line
# 37471             Ecstasy  Carnival Cruise Line
# 176981            Elation  Carnival Cruise Line
# 40247             Fantasy  Carnival Cruise Line
# 243510        Fascination  Carnival Cruise Line
# 245447        Imagination  Carnival Cruise Line
# 237875        Inspiration  Carnival Cruise Line
# 489940        Pacific Sun  Carnival Cruise Line
# 174147           Paradise  Carnival Cruise Line
# 241039          Sensation  Carnival Cruise Line

# %%
df_l.loc[:,['ship_name','major_cruise_line']].drop_duplicates('ship_name').loc[df_l['major_cruise_line'] =='Norwegian Cruise Line'].sort_values('ship_name')   
## 16
# Out:
#                   ship_name      major_cruise_line
# 231174             Albatros  Norwegian Cruise Line
# 34524              Balmoral  Norwegian Cruise Line
# 379596  Norwegian Breakaway  Norwegian Cruise Line
# 279459      Norwegian Crown  Norwegian Cruise Line
# 263994       Norwegian Dawn  Norwegian Cruise Line
# 286427      Norwegian Dream  Norwegian Cruise Line
# 369704       Norwegian Epic  Norwegian Cruise Line
# 353697        Norwegian Gem  Norwegian Cruise Line
# 380540    Norwegian Getaway  Norwegian Cruise Line
# 341899      Norwegian Jewel  Norwegian Cruise Line
# 350585      Norwegian Pearl  Norwegian Cruise Line
# 233621        Norwegian Sea  Norwegian Cruise Line
# 300551        Norwegian Sky  Norwegian Cruise Line
# 338602     Norwegian Spirit  Norwegian Cruise Line
# 256504       Norwegian Star  Norwegian Cruise Line
# 311399        Norwegian Sun  Norwegian Cruise Line

# %%
## Most popular ports, I picked ones I had interest in
#df_l.sort_values('port_city_name').head()
#df_l.groupby('port_city_name').count().head()
#df_l.loc[df_l['port_city_name'] == 'Galveston'].count()    # 1326
#df_l.loc[df_l['port_city_name'] == 'Houston'].count()      # 24
#df_l.loc[df_l['port_city_name'] == 'New Orleans'].count()  # 2044
#df_l.loc[df_l['port_city_name'] == 'Cozumel'].count()      # 6510

# %%
# which ship traveled the most distance?
#df_l['ship_name'].groupby(df_l['major_cruise_line_x']).value_counts()
#df_l['meters_traveled'].groupby(df_l['ship_name']).sum()
df_l['meters_traveled'].groupby(df_l['ship_name']).sum().sort_values(ascending=False).head(10)
# Out:
# ship_name
# Spirit Of Tasmania II      1.596397e+09
# Volendam                   1.308336e+09
# Splendour Of The Seas      1.284162e+09
# Celebrity Solstice         1.263337e+09
# Amsterdam                  1.091302e+09
# Norwegian Pearl            1.067904e+09
# Zaandam                    1.062173e+09
# Celebrity Constellation    1.058205e+09
# Noordam                    1.009234e+09
# Norwegian Spirit           9.992868e+08
# Name: meters_traveled, dtype: float64

# %%
# sort by ship year_built ?
#df_l[['ship_name','year_built']].sort_values('year_built').head(10)
#df_l[['ship_name','year_built']].sort_values('year_built').groupby(df_l['ship_name']).head(10) ## wrong

#df_l[['ship_name','year_built']].groupby(df_l['ship_name']).head(10)  ## not sorted but grouped by ship
#df_l[['ship_name','year_built']].groupby('ship_name').head(10)

#df_l[['ship_name','year_built']].sort_values('year_built').head(10)   ## still duplicate ships
df_l[['ship_name','year_built']].sort_values('year_built').drop_duplicates('ship_name').head(10)

## sort_values can sort on a list of columns ['col1','col2']
## unique() should work but does not
## drop_duplicates
# Out:
#                            ship_name  year_built
# 214383                     Sea Cloud      1931.0
# 159482                     Tustumena      1963.0
# 506376                       Oceanic      1963.0
# 487418                     Matanuska      1963.0
# 487135                     Malaspina      1963.0
# 285735                    Marco Polo      1964.0
# 499747  National Geographic Sea Bird      1966.0
# 502861  National Geographic Sea Lion      1966.0
# 30813              Queen Elizabeth 2      1969.0
# 164395                      The Azur      1971.0

# %%
# what are the newest ships
#df_l[['ship_name','year_built']].sort_values('year_built').drop_duplicates('ship_name').tail(10) # gives NaN
df_l[['ship_name','year_built']].sort_values('year_built').dropna(subset=['year_built']).drop_duplicates('ship_name').tail(10)
# Out:
#                    ship_name  year_built
# 378708        Seabourn Quest      2011.0
# 491603  Celebrity Silhouette      2011.0
# 80252         Costa Favolosa      2011.0
# 81886        Costa Fascinosa      2012.0
# 495563  Celebrity Reflection      2012.0
# 379898   Norwegian Breakaway      2013.0
# 228634   Quantum Of The Seas      2014.0
# 381546     Norwegian Getaway      2014.0
# 229123    Anthem Of The Seas      2015.0
# 164247        Carnival Vista      2016.0

# %%
## need EDA conversion to get this format, also datetime is UTC
# example: df_movies['Released'] = pd.to_datetime(df_movies['Released'], infer_datetime_format=True)
df_l['date'] = pd.to_datetime(df_l['date'], infer_datetime_format=True, format="%y-%m-%d", utc=True) 
## unit='D' instead of default ns

# %%
#df_l.dtypes   ## now datetime64[ns]
## https://docs.scipy.org/doc/numpy-dev/reference/arrays.datetime.html

# %%
# first year a ship sailed (check if 2003 when data begins or shortly after)
df_l[['ship_name','date']].sort_values('date').head()
# Out:
#                  ship_name       date
# 17480   Napoleon Bonaparte 2003-01-01
# 190245         Star Pisces 2003-01-01
# 142769           Statendam 2003-01-01
# 41565              Fantasy 2003-01-01
# 138740              Ryndam 2003-01-01

# %%
# last year a ship sailed
df_l[['ship_name','date']].sort_values('date').tail()
# Out:
#                      ship_name       date
# 173571           MSC Magnifica 2017-06-28
# 496083    Celebrity Reflection 2017-06-28
# 117667          Stad Amsterdam 2017-06-28
# 328923  Brilliance Of The Seas 2017-06-28
# 331463      Legend Of The Seas 2017-06-28

# %%
## inspect missing data ##

# %%
## 3k missing ship names (fixed) ## next time use df_subset ## what is the callsign?
## was 36 with missing cruise line info
#sns.countplot(x='ship_name',data=df_l, hue='ship_name') ## TOO BIG
#df_l[['ship_name','callsign_x']].sort_values('ship_name',ascending=True).drop_duplicates('callsign_x').head(10)
#df_l['ship_name'].sum()  ## bad error, see next cell:
# add: --NotebookApp.iopub_data_rate_limit=10000000      ## 10 Mil
## Riley says AWS lecture on Wednesday, may help
#df_l['ship_name'].value_counts().sum()    ## 506377 which is same a shape
print( df_l.shape)                           ## 506377, 28
df_l.isnull().sum()
# Out:
# (506377, 28)
# ship_name                 0
# callsign                  0
# major_cruise_line         0
# date                      0
# meters_traveled           0
# lat_start                 0
# lon_start                 0
# lat_end                   0
# lon_end                   0
# in_port                   0
# stopped_minutes           0
# num_periods               0
# port_city_id           1232
# port_city_name         1232
# port_city_country      1862
# name                      0
# wiki                   9952
# imo                   60243
# mmsi                  60363
# cruise_line           41888
# year_built            87296
# class                182176
# gross_tonnage         45439
# decks                163510
# capacity              95379
# length               163749
# vessel_type           60243
# flag                  60286
# dtype: int64

# %%
# Error message:
#IOPub data rate exceeded.
#The notebook server will temporarily stop sending output
#to the client in order to avoid crashing it.
#To change this limit, set the config variable
#`--NotebookApp.iopub_data_rate_limit`.

# %%
# num_periods data and stop_minutes are useful together
# 3 tableau plots
# 1 watson plot

# %%
## https://everydaydata.co/2017/07/04/cruse-scraper.html  # blog July 4, 2017

# %%
# what do I want to model ##
## thoughts on using mcmc and pymc3 (except requires python3)
## encapsolate everything you have learned (show it off in portfolio)
## now think about what modeling to use, and what to predict next ##
# a) travel lifespan -- think early, middle, recent (tracing and/or distribution)
# b) rank different carriers
# c) predict congestion (at ports)
# d) predict density (I do not know the distribution)
# e) predict increased traffic trend ## any hypothesis
# f) predict safety (discuss this option)
# g) yearly (macroscopic) stock trend correlate with this data   (Liz would want to by stock in CCL, or favorite)
# h) question: What impact did weather have? Is their correlation?
##   more ... FAQ, ask around ... focus on the business information (BI) perspective

# %%
#from ipyparallel import Client   ## ImportError: No module named ipyparallel

# %%
## now 8 plots to choose, ## 3 stored plots & 1 map plot

# %%
## checkpoint before vessel drop
df_v1 = df_l[df_l.vessel_type == 'passenger']
print( df_v1.shape)              # 1950, 28
df_v2 = df_l[df_l.vessel_type == 'passengers ship']
print( df_v2.shape)              # 356129, 20

df_v = pd.concat([df_v1,df_v2])
print( df_v.shape)               # 358079, 20    ## df_vessel
pd.DataFrame(df_v).to_csv('check_dfv.csv', index=False, encoding='utf-8')  ## 120Meg vs before was 160Meg
## drop everything except "passengers ship" and  "passenger"
# Out:
# (1950, 28)
# (356129, 28)
# (358079, 28)

# %%
# convert in_port bool
df_v['in_port'] = df_v.in_port.map({True: 1, False:0})   ## dont run twice

# %%
df_v.dropna( inplace=True)
print( df_v.shape )                 #141910, 28
print( df_v.isnull().sum() )
print( df_v.dtypes )
# Out:
# (141910, 28)
# ship_name            0
# callsign             0
# major_cruise_line    0
# date                 0
# meters_traveled      0
# lat_start            0
# lon_start            0
# lat_end              0
# lon_end              0
# in_port              0
# stopped_minutes      0
# num_periods          0
# port_city_id         0
# port_city_name       0
# port_city_country    0
# name                 0
# wiki                 0
# imo                  0
# mmsi                 0
# cruise_line          0
# year_built           0
# class                0
# gross_tonnage        0
# decks                0
# capacity             0
# length               0
# vessel_type          0
# flag                 0
# dtype: int64
# ship_name                    object
# callsign                     object
# major_cruise_line            object
# date                 datetime64[ns]
# meters_traveled             float64
# lat_start                   float64
# lon_start                   float64
# lat_end                     float64
# lon_end                     float64
# in_port                       int64
# stopped_minutes               int64
# num_periods                   int64
# port_city_id                 object
# port_city_name               object
# port_city_country            object
# name                         object
# wiki                         object
# imo                         float64
# mmsi                        float64
# cruise_line                  object
# year_built                  float64
# class                        object
# gross_tonnage               float64
# decks                       float64
# capacity                    float64
# length                      float64
# vessel_type                  object
# flag                         object
# dtype: object

# %%
#features= [c for c in df_v.columns \
#           if (not 'wiki' in c) and (not 'imo' in c) and (not 'mmsi' in c) and (not '_end' in c)]
        ## dont need wiki URL,  dont need contact, dont need contact, _end is for Label
#features = ['date','meters_traveled','lat_start','lon_start','in_port','stopped_minutes','num_periods','year_built', 'gross_tonnage', 'decks', 'capacity', 'length' ]
features = [        'meters_traveled','lat_start','lon_start','in_port','stopped_minutes','num_periods','year_built', 'gross_tonnage', 'decks', 'capacity', 'length' ]
# removed datetime[ns]

print( features)  ## numeric for model 
#[ 'meters_traveled', 'lat_start', 'lon_start','in_port', 'stopped_minutes', 'num_periods',
#'year_built', 'gross_tonnage', 'decks', 'capacity', 'length']
# Out:
# ['meters_traveled', 'lat_start', 'lon_start', 'in_port', 'stopped_minutes', 'num_periods', 'year_built', 'gross_tonnage', 'decks', 'capacity', 'length']

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df_v[features].corr(), annot=True)   ## these are features only
                                                 ## not listed is datetime[ns]
plt.title("features Correlation Heatmap")

# %%
X = df_v[features]
y_lat = df_v['lat_end'].values
y_lon = df_v['lon_end'].values

X_train, X_test, y_lat_train, y_lat_test, y_lon_train, y_lon_test = train_test_split(X,y_lat,y_lon) 
# default 30%

# %%
print( X.shape)          # 141910, 11
print( y_lat.shape)      # 141910
print( y_lon.shape)      # same
# Out:
# (141910, 11)
# (141910,)
# (141910,)

# %%
kf = KFold(random_state=2003)                         ## default is 3 fold, conservative
gbr_lat = GradientBoostingRegressor(random_state=2003)
gbr_lon = GradientBoostingRegressor(random_state=2003)

# %%
gbr_lat.fit(X_train, y_lat_train)
gbr_lon.fit(X_train, y_lon_train)

#lat_pred = cross_val_predict(gbr_lat,X_test,y_lat_test, cv=kf)
#lon_pred = cross_val_predict(gbr_lon,X_test,y_lon_test, cv=kf)

#print cross_val_score(gbr_lat, X_test, y_lat_test, cv=kf, scoring='accuracy').mean()  # continuous not supported
#print cross_val_score(gbr_lon, X_test, y_lon_test, cv=kf, scoring='accuracy').mean()  # continuous not supported

# this is R2 score instead for Regression, too good to be true, check if it leaked
print( cross_val_score(gbr_lat, X_test, y_lat_test, cv=kf).mean())  ## .991 R2, very good w/o in_port
print( cross_val_score(gbr_lon, X_test, y_lon_test, cv=kf).mean())  ## .985 R2, very good w/o in_port
                                                                    ## .991 w/in_port  lat
                                                                    ## .989 w/in_port  lon
        ## about 29sec runtime (total for both)
# Out:
# 0.991416823668
# 0.989825981279

# %%
# 8/25 image models is x,y,z but DataFrame is typical spreadsheet style

# %%
from bokeh.io import output_notebook, show
output_notebook()
# BokehJS 0.12.6 successfully loaded.
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f17ee7b1-3592-46e7-b09b-e437f84d3e61">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure
from bokeh.tile_providers import WMTSTileSource

USA = x_range,y_range = ((-13884029,-7453304), (2698291,6455972))  ## this is starting figure

fig = figure(tools='pan, wheel_zoom', x_range=x_range, y_range=y_range)
fig.axis.visible = False
type(USA)
# Out:
# tuple

# %%
url = 'http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png'
attribution = "Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL"
fig.add_tile(WMTSTileSource(url=url, attribution=attribution));
#TitleRenderer(id='...',...)

# %%
def wgs84_to_web_mercator(df, lon="lon", lat="lat"):
    """Converts decimal longitude/latitude to Web Mercator format"""
    k = 6378137
    df["x"] = df[lon] * (k * np.pi/180.0)
    df["y"] = np.log(np.tan((90 + df[lat]) * np.pi/360.0)) * k
    return df

#atx_df = pd.DataFrame(dict(name=["Austin",],lon=[-97.7431,],lat=[30.2672,]))
#wgs84_to_web_mercator(atx_df)
#fig.circle(x=atx_df['x'], y=atx_df['y'],fill_color='red', size=10)

#plot_df = pd.DataFrame(dict(name=["Austin",],lon=[-97.7431,],lat=[30.2672,]))
wgs84_to_web_mercator(plot_df)
fig.circle(x=plot_df['x'], y=plot_df['y'],fill_color='red', size=10)
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a8c68765-8cc5-4c91-ae3c-85a5b0ec07d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a8c68765-8cc5-4c91-ae3c-85a5b0ec07d2");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a8c68765-8cc5-4c91-ae3c-85a5b0ec07d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a8c68765-8cc5-4c91-ae3c-85a5b0ec07d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c8401a3c-15bd-46ce-9c46-32a4eff0fdbc":{"roots":{"references":[{"attributes":{"callback":null,"end":-7453304,"start":-13884029},"id":"c4dfdf8e-7e6d-49b1-968f-57aac36d404a","type":"Range1d"},{"attributes":{"formatter":{"id":"8fae639d-e792-4995-aba0-c2c7d05a9dac","type":"BasicTickFormatter"},"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0acb1f51-28be-4218-9594-4b22cd38b5a3","type":"BasicTicker"},"visible":false},"id":"d1495592-ddde-406f-9fe3-924df210d8f7","type":"LinearAxis"},{"attributes":{},"id":"6a263da3-fdbb-49ba-ae05-9064086ad9d1","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"3da6ff2e-ef88-4c10-a937-7c84f05189b9","type":"PanTool"},{"id":"0617863f-ca3c-4dc7-b656-2e2a676f5074","type":"WheelZoomTool"}]},"id":"0ed0b389-94cc-400c-818f-d3d716a8e5c2","type":"Toolbar"},{"attributes":{"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"}},"id":"0617863f-ca3c-4dc7-b656-2e2a676f5074","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"tcA8TzLeWsE=","dtype":"float64","shape":[1]},"y":{"__ndarray__":"HjK+NQijPkE=","dtype":"float64","shape":[1]}}},"id":"ac204d2d-69eb-4076-8b1b-974d531428cc","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"df859b26-7207-440c-a7cb-a57ca2441214","type":"Circle"},{"attributes":{"formatter":{"id":"81a243cd-74db-4994-a77e-24ed9951188a","type":"BasicTickFormatter"},"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6a263da3-fdbb-49ba-ae05-9064086ad9d1","type":"BasicTicker"},"visible":false},"id":"9acecdeb-7687-418c-a839-0b5c93d9464d","type":"LinearAxis"},{"attributes":{"callback":null,"end":6455972,"start":2698291},"id":"627a07d2-9219-49a7-b73d-5554181f73b2","type":"Range1d"},{"attributes":{},"id":"81a243cd-74db-4994-a77e-24ed9951188a","type":"BasicTickFormatter"},{"attributes":{},"id":"1e17e754-79ad-42a5-b467-c59f94f94587","type":"LinearScale"},{"attributes":{"dimension":1,"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"0acb1f51-28be-4218-9594-4b22cd38b5a3","type":"BasicTicker"}},"id":"c1a88aae-94be-4817-b8fe-b8b7263ac212","type":"Grid"},{"attributes":{},"id":"932691e3-9b5f-42fe-9ba2-e4d7fbe4091f","type":"LinearScale"},{"attributes":{},"id":"8fae639d-e792-4995-aba0-c2c7d05a9dac","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"}},"id":"3da6ff2e-ef88-4c10-a937-7c84f05189b9","type":"PanTool"},{"attributes":{"attribution":"Map tiles by Carto, under CC BY 3.0. Data by OpenStreetMap, under ODbL","url":"http://a.basemaps.cartocdn.com/dark_all/{Z}/{X}/{Y}.png"},"id":"7b2883e5-bced-42da-b172-69f4b24e05e5","type":"WMTSTileSource"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"5cb4a7a6-a18e-4892-bd90-a336fdf24bfb","type":"Circle"},{"attributes":{},"id":"827f9c3d-8c56-47da-a8c7-2b841d9ef6db","type":"ToolEvents"},{"attributes":{"plot":{"id":"9793fd68-62fe-456e-8f78-a02840936e4a","subtype":"Figure","type":"Plot"},"ticker":{"id":"6a263da3-fdbb-49ba-ae05-9064086ad9d1","type":"BasicTicker"}},"id":"216abe1e-a609-42bf-9800-6e4ebd478902","type":"Grid"},{"attributes":{"tile_source":{"id":"7b2883e5-bced-42da-b172-69f4b24e05e5","type":"WMTSTileSource"}},"id":"6aafe150-2b32-429a-9193-28d76b54ea4a","type":"TileRenderer"},{"attributes":{"below":[{"id":"9acecdeb-7687-418c-a839-0b5c93d9464d","type":"LinearAxis"}],"left":[{"id":"d1495592-ddde-406f-9fe3-924df210d8f7","type":"LinearAxis"}],"rendere ...

# %%
# !python --version
# Out:
# Python 2.7.13

# %%
df_v[df_v['date'] == '2017-06-1']
# Out:
#                        ship_name callsign              major_cruise_line  \
# 879            Carnival Splendor     3EUS           Carnival Cruise Line
# 40005                    Ecstasy     H3GR           Carnival Cruise Line
# 58678         Costa Mediterranea     IBCF                 Costa Crociere
# 63966                 Barbarossa     IBJD                 Costa Crociere
# 71971               Costa Magica     IBQQ                 Costa Crociere
# 75159             Costa Luminosa     ICGU                 Costa Crociere
# 80043             Costa Pacifica     ICJA                 Costa Crociere
# 80644             Costa Favolosa     ICPK                 Costa Crociere
# 92568                 Prinsendam     PBGH           Holland America Line
# 94750                  Zuiderdam     PBIG           Holland America Line
# 97998                  Oosterdam     PBKH           Holland America Line
# 102398           Nieuw Amsterdam     PBWQ           Holland America Line
# 123723                   Maasdam     PFRO           Holland America Line
# 161236              Pacific Dawn    2AGH7               Princess Cruises
# 162123          Carnival Freedom    3EBL5           Carnival Cruise Line
# 174021             MSC Magnifica    3FLO4                          Other
# 192364   Celebrity Constellation    9HJB9              Celebrity Cruises
# 202306                Millennium    9HJF9              Celebrity Cruises
# 206827          Celebrity Galaxy    9HJH9              Celebrity Cruises
# 209084         Celebrity Century    9HJI9              Celebrity Cruises
# 210777           Azamara Journey    9HOB8                          Other
# 218556             Azamara Quest    9HOM8                          Other
# 218557             Azamara Quest    9HOM8                          Other
# 218986             Azamara Quest    V7DM6                          Other
# 218987             Azamara Quest    V7DM6                          Other
# 227841         Celebrity Equinox    9HXD9              Celebrity Cruises
# 242079                 Sensation    C6FM8           Carnival Cruise Line
# 248518          Carnival Destiny    C6FN4           Carnival Cruise Line
# 258809            Norwegian Star    C6FR3          Norwegian Cruise Line
# 260934            Seabourn Pride    C6FR5                          Other
# 264576            Norwegian Dawn    C6FT7          Norwegian Cruise Line
# 268904     Navigator Of The Seas    C6FU4  Royal Caribbean International
# 270509      Serenade Of The Seas    C6FV8  Royal Caribbean International
# 302669             Norwegian Sky    C6PZ8          Norwegian Cruise Line
# 305669             Disney Wonder    C6QM8                 Disney Cruises
# 318634      Grandeur Of The Seas    C6SE3  Royal Caribbean International
# 321929      Explorer Of The Seas    C6SE4  Royal Caribbean International
# 322689       Voyager Of The Seas    C6SE5  Royal Caribbean International
# 324263      Radiance Of The Seas    C6SE7  Royal Caribbean International
# 326567        Vision of The Seas    C6SE8  Royal Caribbean International
# 328780    Brilliance Of The Seas    C6SJ5  Royal Caribbean International
# 331477        Legend Of The Seas    C6SL5  Royal Caribbean International
# 347884      Rhapsody Of The Seas    C6UA2  Royal Caribbean International
# 365558  Independence of the Seas    C6WW4  Royal Caribbean International
# 373038         Oasis of the Seas    C6XS7  Royal Caribbean International
# 373733        Allure of the Seas    C6XS8  Royal Caribbean International
# 378916            Seabourn Quest    C6YZ5                          Other
# 433773              Sun Princess    ZCBU6                          Other
# 444818            Coral Princess    ZCDF4               Princess Cruises
# 449445           Island Princess    ZCDG4               Princess Cruises
# 470764                   Ventura    ZCDT2                          Other
# 483466            Queen Victoria    ZCEF3                          Other
#
#              date  meters_traveled  lat_start   lon_start   lat_end  \
# 879    2017-06-01    310792.647117   17.74580  -63.270800  18.46300
# 40005  2017-06-01     86408.169584   31.64620  -79.622300  32.42240
# 58678  2017-06-01    740452.019090   54.86430   10.866400  59.30560
# 63966  2017-06-01    141407.775706   37.21660   24.825000  36.51350
# 71971  2017-06-01    637971.657250   53.90780    5.016840  59.62200
# 75159  2017-06-01    688333.809685   36.66000   23.726500  41.37470
# 80043  2017-06-01     64361.887002   53.89680    8.694560  54.12170
# 80644  2017-06-01    279370.615037   57.17880   11.587800  54.71100
# 92568  2017-06-01    155779.920965   58.98330    4.728790  57.61280
# 94750  2017-06-01    437988.647983   58.20000   22.600000  60.02500
# 97998  2017-06-01     21345.648259   57.00000 -136.100000  56.90000
# 102398 2017-06-01    288718.560094   58.44560 -136.004000  56.30000
# 123723 2017-06-01    283410.533568   45.30000  -60.200000  44.30000
# 161236 2017-06-01         0.000000  -23.20000  158.400000 -23.20000
# 162123 2017-06-01    425948.056499   19.70000  -83.000000  20.59600
# 174021 2017-06-01     40982.329755   59.66960   19.981700  59.32180
# 192364 2017-06-01    503279.337673   40.93650   12.718100  40.25200
# 202306 2017-06-01    344949.304061   58.32090 -136.148000  59.50000
# 206827 2017-06-01    751422.945985   63.64140    7.073380  69.49840
# 209084 2017-06-01         0.000000   32.19180  126.875000  32.19180
# 210777 2017-06-01    197355.486644   36.85880   19.052000  37.38850
# 218556 2017-06-01    233966.167193   42.31890   10.536200  40.94960
# 218557 2017-06-01    233966.167193   42.31890   10.536200  40.94960
# 218986 2017-06-01    304609.039718   56.21270   12.256800  55.83210
# 218987 2017-06-01    304609.039718   56.21270   12.256800  55.83210
# 227841 2017-06-01    126722.455066   11.80000  -68.800000  12.90000
# 242079 2017-06-01    149703.002479   26.10000  -78.500000  25.42190
# 248518 2017-06-01         0.000000   26.10000  -78.300000  26.10000
# 258809 2017-06-01    135809.242739   37.00000   24.900000  36.51540
# 260934 2017-06-01     40580.434615   36.13260   -5.244680  35.97040
# 264576 2017-06-01    123256.543794   37.10000  -66.900000  38.10000
# 268904 2017-06-01    578075.011656   46.60000   -7.200000  50.36290
# 270509 2017-06-01    303433.966400   60.01870   26.576500  59.05900
# 302669 2017-06-01    137681.026516   24.90000  -79.700000  26.09150
# 305669 2017-06-01         0.000000   58.00000 -134.000000  58.00000
# 318634 2017-06-01    222514.376959   36.87360  -75.857500  38.82520
# 321929 2017-06-01    351820.626832   49.70000 -127.800000  48.41590
# 322689 2017-06-01    173062.895269    1.82288  102.408000   1.26594
# 324263 2017-06-01    165404.779998   51.78630 -129.136000  50.78000
# 326567 2017-06-01    216483.445069   49.64210   -5.483830  49.45720
# 328780 2017-06-01    187122.316082   45.43810   12.310700  44.21510
# 331477 2017-06-01    345101.186169   39.85970    1.844000  37.38370
# 347884 2017-06-01    205544.266556   38.10300   20.357100  39.67500
# 365558 2017-06-01     54439.435613   43.77060   -5.051780  43.57770
# 373038 2017-06-01    165521.973030   18.21800  -64.887800  18.12790
# 373733 2017-06-01      4499.838179   18.18710  -64.880000  18.19720
# 378916 2017-06-01    200787.386336   67.47330   13.146800  68.69750
# 433773 2017-06-01         0.000000  -19.70000  155.700000 -19.70000
# 444818 2017-06-01     59451.540133   58.10000 -135.200000  58.43750
# 449445 2017-06-01    256576.803717   59.90000 -145.700000  59.50000
# 470764 2017-06-01    183046.811906   50.11980   -0.230833  51.12620
# 483466 2017-06-01    630068.268526   36.55080   -8.357620  42.10000
#
#            lon_end  in_port       ...               mmsi  \
# 879     -66.109600        0       ...        372808000.0
# 40005   -79.616100        0       ...        353479000.0
# 58678    20.004300        0       ...        247088200.0
# 63966    23.502600        1       ...        247282900.0
# 71971     4.214180        0       ...        247113300.0
# 75159    18.572200        0       ...        247257900.0
# 80043     7.788170        1       ...        247258100.0
# 80644    10.772500        1       ...        247311100.0
# 92568     5.267260        1       ...        244126000.0
# 94750    29.395600        1       ...        245304000.0
# 97998  -135.800000        0       ...        245417000.0
# 102398 -133.300000        0       ...        246648000.0
# 123723  -63.500000        0       ...        244958000.0
# 161236  158.400000        0       ...        235059368.0
# 162123  -86.962600        1       ...        371154000.0
# 174021   19.743900        1       ...        352594000.0
# 192364   18.604600        0       ...        249046000.0
# 202306 -141.700000        0       ...        249055000.0
# 206827   15.582100        0       ...        249051000.0
# 209084  126.875000        0       ...        249054000.0
# 210777   16.930000        1       ...        256204000.0
# 218556   12.669800        1       ...        256216000.0
# 218557   12.669800        1       ...        256216000.0
# 218986   17.106500        0       ...        256216000.0
# 218987   17.106500        0       ...        256216000.0
# 227841  -69.100000        1       ...        249667000.0
# 242079  -79.789500        1       ...        309697000.0
# 248518  -78.300000        0       ...        308017000.0
# 258809   23.502500        1       ...        311082000.0
# 260934   -5.648480        1       ...        311084000.0
# 264576  -67.500000        0       ...        311307000.0
# 268904   -1.795310        0       ...        311478000.0
# 270509   21.542200        1       ...        311492000.0
# 302669  -79.332500        0       ...        308865000.0
# 305669 -134.000000        0       ...        308457000.0
# 318634  -76.404900        1       ...        311315000.0
# 321929 -123.392000        1       ...        311316000.0
# 322689  103.860000        1       ...        311317000.0
# 324263 -127.388000        0       ...        311319000.0
# 326567   -2.499770        1       ...        311321000.0
# 328780   13.936800        1       ...        311361000.0
# 331477   -0.544322        1       ...        311378000.0
# 347884   19.112600        0       ...        311805000.0
# 365558   -5.673100        1       ...        309374000.0
# 373038  -63.325700        1       ...        311020600.0
# 373733  -64.921200        0       ...        311020700.0
# 378916   16.697800        1       ...        311038900.0
# 433773  155.700000        0       ...        310438000.0
# 444818 -135.987000        0       ...        310376000.0
# 449445 -141.200000        0       ...        310384000.0
# 470764    1.819100        1       ...        310562000.0
# 483466   -9.800000        0       ...        310624000.0
#
#                                               cruise_line year_built  \
# 879                                 Carnival Cruise Lines     2008.0
# 40005                               Carnival Cruise Lines     1990.0
# 58678                                      Costa Crociere     2003.0
# 63966                                      Costa Crociere     2010.0
# 71971                                      Costa Crociere     2004.0
# 75159                                      Costa Crociere     2008.0
# 80043                                      Costa Crociere     2008.0
# 80644                                      Costa Crociere     2011.0
# 92568   1988–1994  Royal Viking Line1994–1998  Cunard ...     1988.0
# 94750                                Holland America Line     2002.0
# 97998                                Holland America Line     2003.0
# 102398                               Holland America Line     2010.0
# 123723                               Holland America Line     1993.0
# 161236                                   Princess Cruises     1991.0
# 162123                               Carnival Cruise Line     2007.0
# 174021                                        MSC Cruises     2010.0
# 192364                                  Celebrity Cruises     2001.0
# 202306                                  Celebrity Cruises     2000.0
# 206827  1996—2009: Celebrity Cruises2009 onwards: TUI ...     1996.0
# 209084               Celebrity CruisesSkySea Cruise Lines     1995.0
# 210777                      2007 onwards: Azamara Cruises     2000.0
# 218556  2000–2001: Renaissance Cruises2003–2006: Delph...     2000.0
# 218557  2000–2001: Renaissance Cruises2003–2006: Delph...     2000.0
# 218986  2000–2001: Renaissance Cruises2003–2006: Delph...     2000.0
# 218987  2000–2001: Renaissance Cruises2003–2006: Delph...     2000.0
# 227841                                  Celebrity Cruises     2009.0
# 242079                              Carnival Cruise Lines     1993.0
# 248518                               Carnival Cruise Line     1996.0
# 258809                              Norwegian Cruise Line     2001.0
# 260934  1988-2014: Seabourn Cruise LineWindstar Cruise...     1988.0
# 264576                              Norwegian Cruise Line     2002.0
# 268904                      Royal Caribbean International     2002.0
# 270509                      Royal Caribbean International     2003.0
# 302669                              Norwegian Cruise Line     1999.0
# 305669                                 Disney Cruise Line     1999.0
# 318634                      Royal Caribbean International     1996.0
# 321929                      Royal Caribbean International     2000.0
# 322689                      Royal Caribbean International     1999.0
# 324263                      Royal Caribbean International     2001.0
# 326567                      Royal Caribbean International     1998.0
# 328780                       Royal Caribbean Cruises Ltd.     2002.0
# 331477  Thomson Cruises 2017-PresentRoyal Caribbean In...     1994.0
# 347884                   Royal Caribbean International[1]     1997.0
# 365558                      Royal Caribbean International     2008.0
# 373038                      Royal Caribbean International     2009.0
# 373733                      Royal Caribbean International     2010.0
# 378916                               Seabourn Cruise Line     2011.0
# 433773                               Princess Cruise Line     1995.0
# 444818                                   Princess Cruises     2003.0
# 449445                                   Princess Cruises     2003.0
# 470764                                        P&O Cruises     2008.0
# 483466                                        Cunard Line     2007.0
#
#                                                     class gross_tonnage decks  \
# 879                            Splendor-class cruise ship      113562.0  13.0
# 40005                           Fantasy-class cruise ship       70526.0  12.0
# 58678                            Spirit-class cruise ship       85619.0  12.0
# 63966               Vista/Spirit-class hybrid cruise ship       92720.0  16.0
# 71971                           Fortuna-class cruise ship      102587.0  13.0
# 75159   Hybrid design based on the Vista and Spirit cl...       92720.0  12.0
# 80043                         Concordia-class cruise ship      114425.0  14.0
# 80644                Modified Concordia-class cruise ship      113307.0  13.0
# 92568                                         Cruise ship       39051.0   9.0
# 94750                             Vista class cruise ship       82820.0  11.0
# 97998                             Vista class cruise ship       82820.0  11.0
# 102398                        Signature class cruise ship       86273.0  11.0
# 123723                                S class cruise ship       55575.0  10.0
# 161236                   Crown Princess-class cruise ship       70285.0  11.0
# 162123                         Conquest-class cruise ship      110320.0  13.0
# 174021                           Musica-class cruise ship       95128.0  13.0
# 192364                       Millennium-class cruise ship       90940.0  13.0
# 202306                       Millennium-class cruise ship       90963.0  11.0
# 206827                          Century-class cruise ship       76998.0  10.0
# 209084                          Century-class cruise ship       72458.0  12.0
# 210777                                R-class cruise ship       30277.0  11.0
# 218556                                R-class cruise ship       30277.0  11.0
# 218557                                R-class cruise ship       30277.0  11.0
# 218986                                R-class cruise ship       30277.0  11.0
# 218987                                R-class cruise ship       30277.0  11.0
# 227841                         Solstice-class cruise ship      121878.0  19.0
# 242079                          Fantasy-class cruise ship       70538.0  10.0
# 248518                          Destiny-class cruise ship      103881.0  13.0
# 258809                             Dawn-class cruise ship       91740.0  15.0
# 260934                                  Pride-Class Ships        9975.0   5.0
# 264576                            Libra-class cruise ship       92250.0  15.0
# 268904                          Voyager-class cruise ship      139570.0  15.0
# 270509                         Radiance-class cruise ship       90090.0  12.0
# 302669                              Sun-class cruise ship       77104.0  13.0
# 305669                Magic-class (Disney) cruise ship[2]       83308.0  11.0
# 318634                           Vision-class cruise ship       73817.0  11.0
# 321929                          Voyager-class cruise ship      138194.0  15.0
# 322689                          Voyager-class cruise ship      138194.0  15.0
# 324263                         Radiance class cruise ship       90090.0  13.0
# 326567                           Vision-class cruise ship       78717.0  11.0
# 328780                         Radiance-class cruise ship       90090.0  12.0
# 331477                           Vision-class cruise ship       69472.0  11.0
# 347884                           Vision-class cruise ship       78878.0  12.0
# 365558                          Freedom-class cruise ship      154407.0  15.0
# 373038                            Oasis-class cruise ship      220000.0  16.0
# 373733                            Oasis-class cruise ship      220000.0  16.0
# 378916                             Seabourn Odyssey class       32477.0  11.0
# 433773                              Sun-class cruise ship       77441.0  15.0
# 444818                            Coral-class cruise ship       91627.0  16.0
# 449445                            Coral-class cruise ship       92822.0  16.0
# 470764                            Grand class cruise ship      116017.0  19.0
# 483466                            Vista-class cruise ship       90049.0  16.0
#
#        capacity  length      vessel_type            flag
# 879      3006.0  290.00  passengers ship          PANAMA
# 40005    2056.0  262.00  passengers ship          PANAMA
# 58678    2114.0  292.50  passengers ship           ITALY
# 63966    2828.0  294.00  passengers ship           ITALY
# 71971    3470.0  271.00  passengers ship           ITALY
# 75159    2260.0  294.00  passengers ship           ITALY
# 80043    3780.0  290.20  passengers ship           ITALY
# 80644    3780.0  290.00  passengers ship           ITALY
# 92568     793.0  204.00  passengers ship     NETHERLANDS
# 94750    1916.0  291.00  passengers ship     NETHERLANDS
# 97998    1848.0  290.00  passengers ship     NETHERLANDS
# 102398   2106.0  285.00  passengers ship     NETHERLANDS
# 123723   1258.0  220.00  passengers ship     NETHERLANDS
# 161236   2020.0  245.06  passengers ship  UNITED KINGDOM
# 162123   2974.0  290.00  passengers ship          PANAMA
# 174021   2550.0  293.80  passengers ship          PANAMA
# 192364   2038.0  294.00  passengers ship           MALTA
# 202306   2138.0  294.00  passengers ship           MALTA
# 206827   1870.0  259.70  passengers ship           MALTA
# 209084   1814.0  248.00  passengers ship           MALTA
# 210777    694.0  181.00  passengers ship           MALTA
# 218556    686.0  181.00  passengers ship           MALTA
# 218557    686.0  181.00  passengers ship           MALTA
# 218986    686.0  181.00  passengers ship           MALTA
# 218987    686.0  181.00  passengers ship           MALTA
# 227841   2850.0  317.20  passengers ship           MALTA
# 242079   2056.0   69.00  passengers ship         BAHAMAS
# 248518   3006.0  272.20  passengers ship         BAHAMAS
# 258809   2348.0  294.13  passengers ship         BAHAMAS
# 260934    208.0  133.40  passengers ship         BAHAMAS
# 264576   2340.0  292.00  passengers ship         BAHAMAS
# 268904   3276.0  311.00  passengers ship         BAHAMAS
# 270509   2490.0  293.20  passengers ship         BAHAMAS
# 302669   2004.0  253.60  passengers ship         BAHAMAS
# 305669   2400.0  294.00  passengers ship         BAHAMAS
# 318634   2446.0  279.00  passengers ship         BAHAMAS
# 321929   4029.0  311.00  passengers ship         BAHAMAS
# 322689   3138.0  311.10  passengers ship         BAHAMAS
# 324263   2501.0  293.20  passengers ship         BAHAMAS
# 326567   2435.0  279.00  passengers ship         BAHAMAS
# 328780   2501.0  292.00  passengers ship         BAHAMAS
# 331477   2076.0  264.26  passengers ship         BAHAMAS
# 347884   2435.0  279.00  passengers ship         BAHAMAS
# 365558   4370.0  338.95  passengers ship         BAHAMAS
# 373038   5400.0  360.00  passengers ship         BAHAMAS
# 373733   5400.0  360.00  passengers ship         BAHAMAS
# 378916    450.0  198.15  passengers ship         BAHAMAS
# 433773   2010.0  261.31  passengers ship         BERMUDA
# 444818   1970.0  294.00  passengers ship         BERMUDA
# 449445   1970.0  294.00  passengers ship         BERMUDA
# 470764   3192.0  291.40  passengers ship         BERMUDA
# 483466   2014.0  294.00  passengers ship         BERMUDA
#
# [52 rows x 28 columns]

# %%
df_v[df_v['date'] == '2017-06-1'].index[0]
# Out:
# 879

# %%
df_v[df_v['date'] == '2017-06-1'].shape[0]
# Out:
# 52

# %%
#df_v[df_v['date'] == '2017-06-1']
#plot_df = pd.DataFrame()  # initialize
for i in range(df_v[df_v['date'] == '2017-06-1'].shape[0]):
    #print( df_v[df_v['date'] == '2017-06-1'].iloc[i,0], \
    #       df_v[df_v['date'] == '2017-06-1'].iloc[i,5], \
    #       df_v[df_v['date'] == '2017-06-1'].iloc[i,6] )
    plot_df = pd.DataFrame(dict(name=[df_v[df_v['date'] == '2017-06-1'].iloc[i,0] ,], \
                                lat=[df_v[df_v['date'] == '2017-06-1'].iloc[i,5]  ,], \
                                lon=[df_v[df_v['date'] == '2017-06-1'].iloc[i,6], ] \
                               ))
    wgs84_to_web_mercator(plot_df)
    fig.circle(x=plot_df['x'], y=plot_df['y'],fill_color='red', size=5)
## end-for    
show(fig)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d9b7ad46-eeb1-4da2-8954-a4c862dcb530"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("d9b7ad46-eeb1-4da2-8954-a4c862dcb530");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9b7ad46-eeb1-4da2-8954-a4c862dcb530");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9b7ad46-eeb1-4da2-8954-a4c862dcb530' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"10cb450e-42f8-4df7-87b6-7b3020437993":{"roots":{"references":[{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c770e95-1d0f-4243-842a-58c3cf2cbe1f","type":"Circle"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"4566a652-9bac-412f-9ace-c09601efa1e3","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"c0a2a5ca-a295-43e0-b84a-e37b87d8c2b0","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"88e48e9e-e58d-4ff3-9a20-50638fed0216","type":"Circle"},{"attributes":{"data_source":{"id":"b2df1669-a018-4eb0-a397-16ded1de8ec0","type":"ColumnDataSource"},"glyph":{"id":"ec5182ff-f89c-4100-b681-b970966dbece","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"8f0f9d08-dd7f-44fe-8c66-a127bc577caf","type":"Circle"},"selection_glyph":null},"id":"c1586982-2cc6-4e7f-b3a9-ba089bd43792","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"82eb9419-77c8-48be-8915-6aed9f38dd66","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"52f13cf2-2386-4061-b547-d321953c77ab","type":"Circle"},{"attributes":{"data_source":{"id":"a3f4ae22-ac41-4263-aec3-1b31d3390c0e","type":"ColumnDataSource"},"glyph":{"id":"30db2b29-81d5-4bd1-8797-061ca0f8cffb","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"2293bed0-62c6-48d7-ab1c-17d1344ec4b0","type":"Circle"},"selection_glyph":null},"id":"f3f3b769-93ea-49ec-8bfd-d11cc9234fcc","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"24c096aa-d607-4f51-8c6b-9504203ff1c2","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f2bbfbf7-a986-4d8c-a1b8-59706da4bc3f","type":"Circle"},{"attributes":{"data_source":{"id":"9d6e6046-896b-4aad-a0fb-0e56d8f8b7b9","type":"ColumnDataSource"},"glyph":{"id":"54e61bbc-8224-45bf-be9b-68ffd15a3620","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"323cffd2-df9f-4cec-a72b-b12beabc1ed6","type":"Circle"},"selection_glyph":null},"id":"24146fb0-eb4e-4740-8ede-319ff1c099fd","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"2cd8052d-72da-48b6-88d6-9de9e5be61cc","type":"Circle"},{"attributes":{"data_source":{"id":"b0727ab5-497e-4d70-9166-56c609daad16","type":"ColumnDataSource"},"glyph":{"id":"01e3bac7-9567-43e9-b81a-0783ab8c25b5","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"9125398c-73cb-4c03-b273-55658bbbb3e5","type":"Circle"},"selection_glyph":null},"id":"d7c2c627-db39-4d43-ba1c-e8f25dfaa86a","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"valu ...

# %%
## above plot showing 52 ship on 2017-06-01

# %%
plot_df   ## only the last one
# Out:
#     lat    lon             name             x             y
# 0  59.9 -145.7  Island Princess -1.621925e+07  8.377508e+06
